# %%
# Script dependencies
import pandas as pd
import numpy as np
import pickle
import copy
from surprise import Reader, Dataset
from surprise import SVD, NormalPredictor, BaselineOnly, KNNBasic, NMF
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import streamlit as st

# Importing data
movies_df = pd.read_csv('../resources/data/movies.csv',sep = ',')
ratings_df = pd.read_csv('../resources/data/train.csv')
ratings_df.drop(['timestamp'], axis=1,inplace=True)


# We make use of an SVD model trained on a subset of the MovieLens 10k dataset.
model=pickle.load(open('../resources/models/model.pkl', 'rb'))

# %%
def prediction_item(item_id):
    """Map a given favourite movie to users within the
       MovieLens dataset with the same preference.
    Parameters
    ----------
    item_id : int
        A MovieLens Movie ID.
    Returns
    -------
    list
        User IDs of users with similar high ratings for the given movie.
    """
    # Data preprosessing
    reader = Reader(rating_scale=(0, 5))
    load_df = Dataset.load_from_df(ratings_df,reader)
    a_train = load_df.build_full_trainset()

    predictions = []
    for ui in a_train.all_users():
        predictions.append(model.predict(iid=item_id, uid=ui, verbose = False))
    return predictions

# %%
prediction_item(movies_df.loc[950, 'movieId'])
# Out:
# [Prediction(uid=0, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=1, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=2, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=3, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=4, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=5, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=6, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=7, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=8, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=9, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=10, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=11, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=12, iid=971, r_ui=None, est=3.4279553035677592, details={'was_impossible': False}),
#  Prediction(uid=13, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=14, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=15, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=16, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=17, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=18, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=19, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=20, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=21, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=22, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=23, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=24, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=25, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=26, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=27, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=28, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=29, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=30, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=31, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=32, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=33, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=34, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=35, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=36, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=37, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=38, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=39, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=40, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=41, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=42, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=43, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=44, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=45, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=46, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=47, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=48, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=49, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=50, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=51, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=52, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=53, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=54, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=55, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=56, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=57, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=58, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=59, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=60, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=61, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=62, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=63, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=64, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=65, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=66, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=67, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=68, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=69, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=70, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=71, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=72, iid=971, r_ui=None, est=3.4794897288982476, details={'was_impossible': False}),
#  Prediction(uid=73, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=74, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=75, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=76, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=77, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=78, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=79, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=80, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=81, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=82, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=83, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=84, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=85, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=86, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=87, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=88, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=89, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=90, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=91, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=92, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=93, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=94, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=95, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=96, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=97, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=98, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=99, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=100, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=101, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=102, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=103, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=104, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=105, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=106, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=107, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=108, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=109, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=110, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=111, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=112, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=113, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=114, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=115, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=116, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=117, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=118, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=119, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=120, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=121, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=122, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=123, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=124, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=125, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=126, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=127, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=128, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=129, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=130, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=131, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=132, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=133, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=134, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=135, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=136, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=137, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=138, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=139, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=140, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=141, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=142, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=143, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=144, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=145, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=146, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=147, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=148, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=149, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=150, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=151, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=152, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=153, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=154, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=155, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=156, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=157, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=158, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=159, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=160, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=161, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=162, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=163, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=164, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=165, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=166, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=167, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=168, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=169, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=170, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=171, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=172, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=173, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=174, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=175, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=176, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=177, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=178, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=179, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=180, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=181, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=182, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=183, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=184, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=185, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=186, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=187, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=188, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=189, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=190, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=191, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid
iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=849, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=850, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=851, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=852, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=853, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=854, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=855, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=856, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=857, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=858, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=859, iid=971, r_ui=None, est=3.8271014485910007, details={'was_impossible': False}),
#  Prediction(uid=860, iid=971, r_ui=None, est=2.990955030129945, details={'was_impossible': False}),
#  Prediction(uid=861, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=862, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=863, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=864, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=865, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=866, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=867, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=868, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=869, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=870, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=871, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=872, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=873, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=874, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=875, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=876, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=877, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=878, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=879, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=880, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=881, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=882, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=883, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=884, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=885, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=886, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=887, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=888, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=889, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=890, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=891, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=892, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=893, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=894, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=895, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=896, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=897, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=898, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=899, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=900, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=901, iid=971, r_ui=None, est=3.665036709762132, details={'was_impossible': False}),
#  Prediction(uid=902, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=903, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=904, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=905, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=906, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=907, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=908, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=909, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=910, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=911, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=912, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=913, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=914, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=915, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=916, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=917, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=918, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=919, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=920, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=921, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=922, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=923, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=924, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=925, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=926, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=927, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=928, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=929, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=930, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=931, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=932, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=933, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=934, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=935, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=936, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=937, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=938, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=939, iid=971, r_ui=None, est=4.01087388741632, details={'was_impossible': False}),
#  Prediction(uid=940, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=941, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=942, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=943, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=944, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=945, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=946, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=947, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=948, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=949, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=950, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=951, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=952, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=953, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=954, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=955, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=956, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=957, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=958, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=959, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=960, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=961, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=962, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=963, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=964, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=965, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=966, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=967, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=968, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=969, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=970, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=971, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=972, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=973, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=974, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=975, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=976, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=977, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=978, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=979, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=980, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=981, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=982, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=983, iid=971, r_ui=None, est=3.2283210786699814, details={'was_impossible': False}),
#  Prediction(uid=984, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=985, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=986, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=987, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=988, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=989, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=990, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=991, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=992, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=993, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=994, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=995, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=996, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=997, iid=971, r_ui=None, est=3.4644702614287035, details={'was_impossible': False}),
#  Prediction(uid=998, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  Prediction(uid=999, iid=971, r_ui=None, est=3.449619940002398, details={'was_impossible': False}),
#  ...]

# %%
def pred_movies(movie_list):
    """Maps the given favourite movies selected within the app to corresponding
    users within the MovieLens dataset.
    Parameters
    ----------
    movie_list : list
        Three favourite movies selected by the app user.
    Returns
    -------
    list
        User-ID's of users with similar high ratings for each movie.
    """
    # Store the id of users
    id_store=[]
    # For each movie selected by a user of the app,
    # predict a corresponding user within the dataset with the highest rating
    for i in movie_list:
        predictions = prediction_item(item_id = i)
        predictions.sort(key=lambda x: x.est, reverse=True)
        # Take the top 10 user id's from each movie with highest rankings
        for pred in predictions[:10]:
            id_store.append(pred.uid)
    # Return a list of user id's
    return id_store

# %%
pred_movies(movies_df.loc[100:102, 'title'])
# Out:
# [18551,
#  21365,
#  6118,
#  44782,
#  50739,
#  31547,
#  53150,
#  39251,
#  11315,
#  3403,
#  18551,
#  21365,
#  6118,
#  44782,
#  50739,
#  31547,
#  53150,
#  39251,
#  11315,
#  3403,
#  18551,
#  21365,
#  6118,
#  44782,
#  50739,
#  31547,
#  53150,
#  39251,
#  11315,
#  3403]

# %%
def collab_model(movie_list,top_n=10):
    """Performs Collaborative filtering based upon a list of movies supplied
       by the app user.
    Parameters
    ----------
    movie_list : list (str)
        Favorite movies chosen by the app user.
    top_n : type
        Number of top recommendations to return to the user.
    Returns
    -------
    list (str)
        Titles of the top-n movie recommendations to the user.
    """
    indices = pd.Series(movies_df['title'])
    movie_ids = pred_movies(movie_list)
    
    df_init_users = ratings_df[ratings_df['userId'] == movie_ids[0]]
    
    for i in movie_ids :
        df_init_users = df_init_users.append(ratings_df[ratings_df['userId']==i])
    
    # Getting the cosine similarity matrix
    cosine_sim = cosine_similarity(np.array(df_init_users), np.array(df_init_users))
    
    idx_1 = indices[indices == list(movie_list)[0]].index % len(cosine_sim)
    idx_2 = indices[indices == list(movie_list)[1]].index % len(cosine_sim)
    idx_3 = indices[indices == list(movie_list)[2]].index % len(cosine_sim)
    
    # Creating a Series with the similarity scores in descending order
    rank_1 = cosine_sim[idx_1][0]
    rank_2 = cosine_sim[idx_2][0]
    rank_3 = cosine_sim[idx_3][0]
   
    # Calculating the scores
    score_series_1 = pd.Series(rank_1).sort_values(ascending = False)
    score_series_2 = pd.Series(rank_2).sort_values(ascending = False)
    score_series_3 = pd.Series(rank_3).sort_values(ascending = False)
    
     # Appending the names of movies
    listings = score_series_1.append(score_series_1).append(score_series_3).sort_values(ascending = False)
    
    recommended_movies = []
    # Choose top 50
    top_50_indexes = list(listings.iloc[1:50].index)

    # Removing chosen movies
    top_indexes = np.setdiff1d(top_50_indexes,[idx_1,idx_2,idx_3])
    for i in top_indexes[:top_n]:
        recommended_movies.append(list(movies_df['title'])[i])
        
    return recommended_movies

# %%
collab_model(movies_df.loc[14930:14933, 'title'])
# Out:
# 2022-07-29 14:41:35.140
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ["Singin' in the Rain (1952)",
#  'Funny Face (1957)',
#  "Breakfast at Tiffany's (1961)",
#  'Vertigo (1958)',
#  'Rear Window (1954)',
#  'Hamlet (1948)',
#  'Greatest Show on Earth, The (1952)',
#  'From Here to Eternity (1953)',
#  'On the Waterfront (1954)',
#  'Marty (1955)']

# %%
collab_model(movies_df.loc[14000:14003, 'title'])
# Out:
# [18551 21365  6118 31547 53150]

# %%
movies_df.loc[14930:14933, 'title']
# Out:
# 14930       So Proudly We Hail! (1943)
# 14931          31 North 62 East (2009)
# 14932             Irene in Time (2009)
# 14933    Captains of the Clouds (1942)
# Name: title, dtype: object

# %%
ratings_df.shape
# Out:
# (100004, 3)

# %%
ratings_df.tail()
# Out:
#         userId  movieId  rating
# 99999      671     6268     2.5
# 100000     671     6269     4.0
# 100001     671     6365     4.0
# 100002     671     6385     2.5
# 100003     671     6565     3.5
